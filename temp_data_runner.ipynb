# %% [markdown]
# ## Temporary loops to call script for list of dates

# %%
import numpy as np
import make_dashboard
from astropy.io import fits
import time

# %%
dates = []
for n in range(1,32):
    dates.append('2025-07-'+f'{n:02}')
for n in range(1,32):
    dates.append('2025-08-'+f'{n:02}')
for n in range(1,31):
    dates.append('2025-09-'+f'{n:02}')
print(len(dates))
print(dates)

# %%
for date in dates:
    print(str(date))
    # !{'python make_dashboard.py '+date+' 350 -7 4 True'}
    print('')

# %%
#!ls
#time.sleep(1.3) # Seconds
files = !{'ls data'}
print(len(files))
for file in files:
    file_name = file.strip('.npy')
    #cmd = 'python make_dashboard.py '+file_name+' 350 -7 4'
    #print(cmd)
    # !{'python make_dashboard.py '+file_name+' 350 -7 4'}
    time.sleep(2)
    print('')

# %% [markdown]
# # Tests:

# %% [markdown]
# ### Make new file only

# %%
# !{'python make_dashboard.py 2025-09-19 350 -7 4 False'}

# %% [markdown]
# ### Make dashboard from existing file

# %%
# !{'python make_dashboard.py 2025-09-19 350 -7 4'}

# %% [markdown]
# ### Make new file and make dashboard

# %%
# !{'python make_dashboard.py 2025-09-20 350 -7 4'}

# %% [markdown]
# ### Not making dashboard but file already exists

# %%
# !{'python make_dashboard.py 2025-09-19 350 -7 4 False'}
