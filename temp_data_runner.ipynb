# %%
import numpy as np
import make_dashboard

# %%
dates = []
for n in range(1,32):
    dates.append('2025-07-'+f'{n:02}')
#for n in range(1,32):
#    dates.append('2025-08-'+f'{n:02}')
#for n in range(1,31):
#    dates.append('2025-09-'+f'{n:02}')
print(len(dates))

# %%
for date in dates:
    print(str(date))
    # !{'python make_dashboard.py '+date+' 350 -7 4'}
    print('')

# %%
loaded_array = np.load('data/2025-07-07.npy', allow_pickle=True)
